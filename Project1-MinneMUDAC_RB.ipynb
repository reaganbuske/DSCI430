# %%
import pandas as pd

# %%
# !head -n 5 ./data/MinneMUDAC_raw_files/2002_metro_tax_parcels.txt
# Out:
# ACRES_DEED|ACRES_POLY|AGPRE_ENRD|AGPRE_EXPD|AG_PRESERV|BASEMENT|BLDG_NUM|BLOCK|CITY|CITY_USPS|COOLING|COUNTY_ID|DWELL_TYPE|EMV_BLDG|EMV_LAND|EMV_TOTAL|FIN_SQ_FT|GARAGE|GARAGESQFT|GREEN_ACRE|HEATING|HOMESTEAD|HOME_STYLE|LANDMARK|LOT|MULTI_USES|NUM_UNITS|OPEN_SPACE|OWNER_MORE|OWNER_NAME|OWN_ADD_L1|OWN_ADD_L2|OWN_ADD_L3|OWN_NAME|PARC_CODE|PIN|PIN_1|PLAT_NAME|PREFIXTYPE|PREFIX_DIR|SALE_DATE|SALE_VALUE|SCHOOL_DST|SPEC_ASSES|STREET|STREETNAME|STREETTYPE|STRUC_TYPE|SUFFIX_DIR|Shape_Area|Shape_Leng|TAX_ADD_L1|TAX_ADD_L2|TAX_ADD_L3|TAX_ADD_LI|TAX_CAPAC|TAX_EXEMPT|TAX_NAME|TOTAL_TAX|UNIT_INFO|USE1_DESC|USE2_DESC|USE3_DESC|USE4_DESC|WSHD_DIST|XUSE1_DESC|XUSE2_DESC|XUSE3_DESC|XUSE4_DESC|YEAR_BUILT|Year|ZIP|ZIP4|centroid_lat|centroid_long
# ...

# %%
from toolz import first
file_iter = pd.read_csv('./data/MinneMUDAC_raw_files/2002_metro_tax_parcels.txt', sep= '|', chunksize = 500)
first_chunk02 = first(file_iter)
first_chunk02.columns
# Out:
# Index(['ACRES_DEED', 'ACRES_POLY', 'AGPRE_ENRD', 'AGPRE_EXPD', 'AG_PRESERV',
#        'BASEMENT', 'BLDG_NUM', 'BLOCK', 'CITY', 'CITY_USPS', 'COOLING',
#        'COUNTY_ID', 'DWELL_TYPE', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#        'FIN_SQ_FT', 'GARAGE', 'GARAGESQFT', 'GREEN_ACRE', 'HEATING',
#        'HOMESTEAD', 'HOME_STYLE', 'LANDMARK', 'LOT', 'MULTI_USES', 'NUM_UNITS',
#        'OPEN_SPACE', 'OWNER_MORE', 'OWNER_NAME', 'OWN_ADD_L1', 'OWN_ADD_L2',
#        'OWN_ADD_L3', 'OWN_NAME', 'PARC_CODE', 'PIN', 'PIN_1', 'PLAT_NAME',
#        'PREFIXTYPE', 'PREFIX_DIR', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#        'SPEC_ASSES', 'STREET', 'STREETNAME', 'STREETTYPE', 'STRUC_TYPE',
#        'SUFFIX_DIR', 'Shape_Area', 'Shape_Leng', 'TAX_ADD_L1', 'TAX_ADD_L2',
#        'TAX_ADD_L3', 'TAX_ADD_LI', 'TAX_CAPAC', 'TAX_EXEMPT', 'TAX_NAME',
#        'TOTAL_TAX', 'UNIT_INFO', 'USE1_DESC', 'USE2_DESC', 'USE3_DESC',
#        'USE4_DESC', 'WSHD_DIST', 'XUSE1_DESC', 'XUSE2_DESC', 'XUSE3_DESC',
# ...

# %%
file_iter = pd.read_csv('./data/MinneMUDAC_raw_files/2003_metro_tax_parcels.txt', sep= '|', chunksize = 500)
first_chunk03 = first(file_iter)
first_chunk03.columns
# Out:
# Index(['BLDG_NUM', 'CITY', 'COUNTY_ID', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#        'HOMESTEAD', 'NUM_UNITS', 'OWN_ADD_L1', 'OWN_ADD_L2', 'OWN_ADD_L3',
#        'OWN_NAME', 'PARC_CODE', 'PIN', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#        'STREET', 'STRUC_TYPE', 'Shape_Area', 'Shape_Leng', 'TAX_ADD_L1',
#        'TAX_ADD_L2', 'TAX_ADD_L3', 'TAX_CAPAC', 'TAX_EXEMPT', 'TAX_NAME',
#        'TOTAL_TAX', 'WSHD_DIST', 'YEAR_BUILT', 'Year', 'ZIP', 'centroid_long',
#        'centroid_lat'],
#       dtype='object')

# %%
acc = set([])
for col in first_chunk02.columns:
    acc = set(first_chunk02.columns)
acc
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %%
acc1 = set([])
for col in first_chunk03.columns:
    acc1 = set(first_chunk03.columns)
acc1
# Out:
# {'BLDG_NUM',
#  'CITY',
#  'COUNTY_ID',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'HOMESTEAD',
#  'NUM_UNITS',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'STREET',
#  'STRUC_TYPE',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'WSHD_DIST',
#  'YEAR_BUILT',
#  'Year',
#  'ZIP',
#  'centroid_lat',
#  'centroid_long'}

# %%
acc.intersection(acc1)
# Out:
# {'BLDG_NUM',
#  'CITY',
#  'COUNTY_ID',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'HOMESTEAD',
#  'NUM_UNITS',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'STREET',
#  'STRUC_TYPE',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'WSHD_DIST',
#  'YEAR_BUILT',
#  'Year',
#  'ZIP',
#  'centroid_lat',
#  'centroid_long'}

# %%
acc.union(acc1)
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
# ...

# %%
acc.difference(acc1)
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLOCK',
#  'CITY_USPS',
#  'COOLING',
#  'DWELL_TYPE',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SPEC_ASSES',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'TAX_ADD_LI',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
#  'USE4_DESC',
#  'XUSE1_DESC',
#  'XUSE2_DESC',
#  'XUSE3_DESC',
#  'XUSE4_DESC',
#  'ZIP4'}

# %%
def filename(year):
    base = './data/MinneMUDAC_raw_files/{}_metro_tax_parcels.txt'
    return (base.format(year))

# %%
#filenames = [filename(year) for year in range(2002,2016)]
#filenames = [filename(year) for year in range(2002,2016) if year != 2003]
filenames = [filename(year) for year in range(2004,2015)]
filenames
# Out:
# ['./data/MinneMUDAC_raw_files/2004_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2005_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2006_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2007_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2008_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2009_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2010_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2011_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2012_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2013_metro_tax_parcels.txt',
#  './data/MinneMUDAC_raw_files/2014_metro_tax_parcels.txt']

# %%
fileiterator = [pd.read_csv(file, chunksize = 500, sep = '|') for file in filenames]
fileiterator

# %%
firstchunk = [first(ele).columns for ele in fileiterator]
firstchunk
# Out:
# [Index(['ACRES_DEED', 'ACRES_POLY', 'AGPRE_ENRD', 'AGPRE_EXPD', 'AG_PRESERV',
#         'BASEMENT', 'BLDG_NUM', 'BLOCK', 'CITY', 'CITY_USPS', 'COOLING',
#         'COUNTY_ID', 'DWELL_TYPE', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#         'FIN_SQ_FT', 'GARAGE', 'GARAGESQFT', 'GREEN_ACRE', 'HEATING',
#         'HOMESTEAD', 'HOME_STYLE', 'ID', 'LANDMARK', 'LOT', 'MULTI_USES',
#         'NUM_UNITS', 'OPEN_SPACE', 'OWNER_MORE', 'OWNER_NAME', 'OWN_ADD_L1',
#         'OWN_ADD_L2', 'OWN_ADD_L3', 'PARC_CODE', 'PIN', 'PLAT_NAME',
#         'PREFIXTYPE', 'PREFIX_DIR', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#         'SPEC_ASSES', 'STREETNAME', 'STREETTYPE', 'SUFFIX_DIR', 'Shape_Area',
#         'Shape_Leng', 'TAX_ADD_L1', 'TAX_ADD_L2', 'TAX_ADD_L3', 'TAX_CAPAC',
#         'TAX_EXEMPT', 'TAX_NAME', 'TOTAL_TAX', 'UNIT_INFO', 'USE1_DESC',
#         'USE2_DESC', 'USE3_DESC', 'USE4_DESC', 'WSHD_DIST', 'XUSE1_DESC',
#         'XUSE2_DESC', 'XUSE3_DESC', 'XUSE4_DESC', 'YEAR_BUILT', 'Year', 'ZIP',
# ...

# %%
col_name_sets = [set(ele) for ele in firstchunk]
col_name_sets
# Out:
# [{'ACRES_DEED',
#   'ACRES_POLY',
#   'AGPRE_ENRD',
#   'AGPRE_EXPD',
#   'AG_PRESERV',
#   'BASEMENT',
#   'BLDG_NUM',
#   'BLOCK',
#   'CITY',
#   'CITY_USPS',
#   'COOLING',
#   'COUNTY_ID',
#   'DWELL_TYPE',
#   'EMV_BLDG',
#   'EMV_LAND',
#   'EMV_TOTAL',
#   'FIN_SQ_FT',
#   'GARAGE',
#   'GARAGESQFT',
#   'GREEN_ACRE',
#   'HEATING',
#   'HOMESTEAD',
#   'HOME_STYLE',
#   'ID',
#   'LANDMARK',
#   'LOT',
#   'MULTI_USES',
#   'NUM_UNITS',
#   'OPEN_SPACE',
#   'OWNER_MORE',
#   'OWNER_NAME',
#   'OWN_ADD_L1',
#   'OWN_ADD_L2',
#   'OWN_ADD_L3',
#   'PARC_CODE',
#   'PIN',
#   'PLAT_NAME',
#   'PREFIXTYPE',
#   'PREFIX_DIR',
#   'SALE_DATE',
#   'SALE_VALUE',
#   'SCHOOL_DST',
#   'SPEC_ASSES',
#   'STREETNAME',
#   'STREETTYPE',
#   'SUFFIX_DIR',
#   'Shape_Area',
#   'Shape_Leng',
#   'TAX_ADD_L1',
#   'TAX_ADD_L2',
#   'TAX_ADD_L3',
#   'TAX_CAPAC',
#   'TAX_EXEMPT',
#   'TAX_NAME',
#   'TOTAL_TAX',
#   'UNIT_INFO',
#   'USE1_DESC',
#   'USE2_DESC',
#   'USE3_DESC',
# ...

# %%
[(year, len(h)) for year, h in zip(range(2004,2015), col_name_sets)]
# Out:
# [(2004, 71),
#  (2005, 70),
#  (2006, 70),
#  (2007, 72),
#  (2008, 72),
#  (2009, 72),
#  (2010, 71),
#  (2011, 70),
#  (2012, 70),
#  (2013, 70),
#  (2014, 74)]

# %%
acc_un = set([])
for cols in col_name_sets:
    acc_un = acc_un.union(cols)
acc_un
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'Garage',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'Homestead',
#  'ID',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'PARC_CODE',
#  'PIN',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Le_1',
#  'Shape_Leng',
#  'Shape_STAr',
#  'Shape_STLe',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TORRENS',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
# ...

# %%
acc_undf = pd.DataFrame(acc_un)
acc_undf
# Out:
#                 0
# 0      OWN_ADD_L2
# 1      YEAR_BUILT
# 2         COOLING
# 3       PARC_CODE
# 4       SALE_DATE
# 5      TAX_ADD_L2
# 6       USE4_DESC
# 7            ZIP4
# 8          Garage
# 9         HEATING
# 10           Year
# 11     Shape_STAr
# 12     SALE_VALUE
# 13      USE3_DESC
# 14      NUM_UNITS
# 15      PLAT_NAME
# 16       BLDG_NUM
# 17     Shape_Le_1
# 18             ID
# 19      WSHD_DIST
# 20            LOT
# 21      USE1_DESC
# 22      COUNTY_ID
# 23       BASEMENT
# 24     DWELL_TYPE
# 25      FIN_SQ_FT
# 26     ACRES_POLY
# 27      HOMESTEAD
# 28      TOTAL_TAX
# 29          BLOCK
# ..            ...
# 47     SPEC_ASSES
# 48     SUFFIX_DIR
# 49       LANDMARK
# 50     OWN_ADD_L1
# 51     XUSE2_DESC
# 52       EMV_LAND
# 53     MULTI_USES
# 54       TAX_NAME
# 55     Shape_Leng
# 56      UNIT_INFO
# 57        TORRENS
# 58     AG_PRESERV
# 59     ACRES_DEED
# 60     AGPRE_EXPD
# 61     PREFIXTYPE
# 62  centroid_long
# 63            ZIP
# 64     TAX_EXEMPT
# ...

# %%
#acc_undf.to_csv('./data/parcel_common_columns_2004_2014.csv', index = False)

# %%
acc_in = col_name_sets[1]
for cols in col_name_sets[2:]:
    acc_in = acc_in.intersection(cols)
acc_in
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'PARC_CODE',
#  'PIN',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
#  'USE4_DESC',
#  'WSHD_DIST',
#  'XUSE1_DESC',
#  'XUSE2_DESC',
# ...

# %%
acc_indf = pd.DataFrame(acc_in)
acc_indf
# Out:
#                 0
# 0      OWN_ADD_L2
# 1      YEAR_BUILT
# 2         COOLING
# 3      GREEN_ACRE
# 4       PARC_CODE
# 5       EMV_TOTAL
# 6       SALE_DATE
# 7      TAX_ADD_L2
# 8       CITY_USPS
# 9       USE4_DESC
# 10           ZIP4
# 11        HEATING
# 12           Year
# 13         GARAGE
# 14     SCHOOL_DST
# 15     SALE_VALUE
# 16      USE3_DESC
# 17      NUM_UNITS
# 18      PLAT_NAME
# 19     SPEC_ASSES
# 20     SUFFIX_DIR
# 21       LANDMARK
# 22       BLDG_NUM
# 23     OWN_ADD_L1
# 24      WSHD_DIST
# 25     XUSE2_DESC
# 26            LOT
# 27       EMV_LAND
# 28      COUNTY_ID
# 29       BASEMENT
# ..            ...
# 40      TOTAL_TAX
# 41     ACRES_DEED
# 42     AGPRE_EXPD
# 43          BLOCK
# 44     GARAGESQFT
# 45      USE2_DESC
# 46      TAX_CAPAC
# 47     PREFIXTYPE
# 48     XUSE1_DESC
# 49     AGPRE_ENRD
# 50  centroid_long
# 51            ZIP
# 52     TAX_ADD_L3
# 53           CITY
# 54     TAX_EXEMPT
# 55     HOME_STYLE
# 56     TAX_ADD_L1
# 57     XUSE3_DESC
# ...

# %%
acc_indf.to_csv('./data/parcel_common_columns_2004_2014.csv', index = False)

# %%
extra_cols = [(n,len(s)) for (n, s) in zip(filenames, col_name_sets) if (len(s) > len(acc_in))]
extra_cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1bfe614e0d0e> in <module>()
# ----> 1 extra_cols = [(n,len(s)) for (n, s) in zip(filenames, col_name_sets) if (len(s) > len(acc_in))]
#       2 extra_cols
#
# <ipython-input-19-1bfe614e0d0e> in <listcomp>(.0)
# ----> 1 extra_cols = [(n,len(s)) for (n, s) in zip(filenames, col_name_sets) if (len(s) > len(acc_in))]
#       2 extra_cols
#
# NameError: name 'acc_in' is not defined

# %%
difs = [(i, (c).difference(acc_in)) for i, c in zip(range(2002,2016),col_name_sets)]
difs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4cf028a21766> in <module>()
# ----> 1 difs = [(i, (c).difference(acc_in)) for i, c in zip(range(2002,2016),col_name_sets)]
#       2 difs
#
# <ipython-input-20-4cf028a21766> in <listcomp>(.0)
# ----> 1 difs = [(i, (c).difference(acc_in)) for i, c in zip(range(2002,2016),col_name_sets)]
#       2 difs
#
# NameError: name 'acc_in' is not defined

# %%
len_difs = [(i, len((c).difference(acc_in))) for i, c in zip(range(2002,2016), col_name_sets)]
len_difs
# Out:
# [(2002, 1),
#  (2003, 0),
#  (2004, 0),
#  (2005, 2),
#  (2006, 2),
#  (2007, 2),
#  (2008, 1),
#  (2009, 0),
#  (2010, 0),
#  (2011, 0),
#  (2012, 4),
#  (2013, 0)]
